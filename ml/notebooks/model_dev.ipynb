# %% [markdown]
# # Advanced Movie Recommender — Model Development
#
# Write all your data processing, feature engineering, and model training here.
# Export trained artifacts (`.pkl` files) to `ml/models/` at the end of each section.

# %%
import pandas as pd
import pickle

# Load raw data
# movies = pd.read_csv('../data/raw/tmdb_5000_movies.csv')
# credits = pd.read_csv('../data/raw/tmdb_5000_credits.csv')
